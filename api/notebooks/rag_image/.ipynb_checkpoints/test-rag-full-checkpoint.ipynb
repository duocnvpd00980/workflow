# %%
# CELL 1: IMPORT..............

import sys
sys.path.insert(0, '/home/duoc/workflow/api')

import requests
from io import BytesIO
from PIL import Image

from app.rag.services.base import ................
from app.rag.services................. import .........................

..............
print('✅ Import OK')
