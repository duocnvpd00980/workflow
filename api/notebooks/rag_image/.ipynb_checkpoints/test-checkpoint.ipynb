# %%
import nest_asyncio
nest_asyncio.apply()  # Cho phép nest event loop trong Jupyter

import sys
sys.path.insert(0, "/home/duoc/workflow/api")  # thư mục chứa folder app/
print("Cấu hình sys.path thành công! Thư mục hiện tại:")
# Out:
# Cấu hình sys.path thành công! Thư mục hiện tại:

# %%
import json
from pathlib import Path

dp = Path("/home/duoc/workflow/api/rag_storage/image/data.json")
with open(dp) as f:
    d = json.load(f)
print("IDs:", d["ids"])
print("Total:", len(d["ids"]))
# Out:
# IDs: ['product-001', 'STANDARD DOUBLE THƯỜNG – PHÒNG 2', 'product-002', 'product-003']
# Total: 4

# %%
import os
print("CWD:", os.getcwd())
print("RAG storage:", list(Path("./rag_storage").rglob("*")) if Path("./rag_storage").exists() else "NOT FOUND")
# Out:
# CWD: /home/duoc/workflow/api/notebooks/rag_image
# RAG storage: [PosixPath('rag_storage/image')]
