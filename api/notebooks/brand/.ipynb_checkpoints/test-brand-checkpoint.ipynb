# %%
import nest_asyncio
nest_asyncio.apply()  # Cho phép nest event loop trong Jupyter

import sys
sys.path.insert(0, "/home/duoc/workflow/api")  # thư mục chứa folder app/
print("Cấu hình sys.path thành công! Thư mục hiện tại:")
import os
os.chdir("/home/duoc/workflow/api")  # Thêm dòng này TRƯỚC khi import app
# Out:
# Cấu hình sys.path thành công! Thư mục hiện tại:

# %%
data = {
  "task": {
    "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
    "business_name": "moc quan nha trang",
    "status": "done",
    "updated_at": "2026-06-20T12:24:35.916843",
    "id": 2,
    "query": "nhà hàng quán nhậu hải sản Đà Nẵng",
    "fb_url": "https://www.facebook.com/mocseafood/",
    "error": "null"
  },
  "result": {
    "business_name": "moc quan nha trang",
    "suggestions_raw": [
      "nhà hàng quán nhậu hải sản đà nẵng giá bao nhiêu",
      "nhà hàng quán nhậu hải sản đà nẵng 5 sao",
      "nhà hàng quán nhậu hải sản đà nẵng nào đẹp",
      "nhà hàng quán nhậu hải sản đà nẵng cho trẻ em",
      "nhà hàng quán nhậu hải sản đà nẵng gần đây",
      "nhà hàng quán nhậu hải sản đà nẵng ngon nhất",
      "nhà hàng quán nhậu hải sản đà nẵng a lưới",
      "nhà hàng quán nhậu hải sản đà nẵng cho bé",
      "nhà hàng quán nhậu hải sản đà nẵng giá",
      "nhà hàng quán nhậu hải sản đà nẵng ở đà nẵng",
      "nhà hàng quán nhậu hải sản đà nẵng tuy hòa",
      "nhà hàng quán nhậu hải sản đà nẵng rẻ nhất",
      "nhà hàng quán nhậu hải sản đà nẵng ở sài gòn",
      "nhà hàng quán nhậu hải sản đà nẵng tại đà nẵng",
      "nhà hàng quán nhậu hải sản đà nẵng rẻ",
      "nhà hàng quán nhậu hải sản đà nẵng gần biển",
      "nhà hàng quán nhậu hải sản đà nẵng 500k",
      "nhà hàng quán nhậu hải sản đà nẵng chotot",
      "nhà hàng quán nhậu hải sản đà nẵng đẹp nhất",
      "nhà hàng quán nhậu hải sản đà nẵng 30k",
      "nhà hàng quán nhậu hải sản đà nẵng reviews",
      "nhà hàng quán nhậu hải sản đà nẵng cho thuê",
      "nhà hàng quán nhậu hải sản đà nẵng 100k",
      "nhà hàng quán nhậu hải sản đà nẵng rẻ ngon",
      "nhà hàng quán nhậu hải sản đà nẵng giá rẻ",
      "nhà hàng quán nhậu hải sản đà nẵng nổi tiếng",
      "nhà hàng quán nhậu hải sản đà nẵng review",
      "nhà hàng quán nhậu hải sản đà nẵng giá vé",
      "nhà hàng quán nhậu hải sản đà nẵng 30/4",
      "nhà hàng quán nhậu hải sản đà nẵng tuyển dụng",
      "nhà hàng quán nhậu hải sản đà nẵng 1990",
      "nhà hàng quán nhậu hải sản đà nẵng ngon",
      "nhà hàng quán nhậu hải sản đà nẵng nào ngon",
      "nhà hàng quán nhậu hải sản đà nẵng gần nhất",
      "nhà hàng quán nhậu hải sản đà nẵng 1980",
      "nhà hàng quán nhậu hải sản đà nẵng ở nha trang",
      "nhà hàng quán nhậu hải sản đà nẵng ở đâu ngon",
      "nhà hàng quán nhậu hải sản đà nẵng tại nha trang",
      "nhà hàng quán nhậu hải sản đà nẵng ngon rẻ",
      "nhà hàng quán nhậu hải sản đà nẵng a-z",
      "nhà hàng quán nhậu hải sản đà nẵng 199k"
    ],
    "id": 2,
    "serp_data": {
      "top_urls": [
        {
          "position": 1,
          "title": "10 quán hải sản giá rẻ ngon nức tiếng ở Đà Nẵng, mà bạn có ...",
          "url": "https://www.bachhoaxanh.com/kinh-nghiem-hay/10-quan-hai-san-gia-re-ngon-nuc-tieng-o-da-nang-ma-ban-co-the-de-dang-tim-thay-1406465",
          "domain": "www.bachhoaxanh.com",
          "type": "organic"
        },
        {
          "position": 2,
          "title": "10 Quán hải sản ở Đà Nẵng nổi tiếng, tươi ngon, chất lượng",
          "url": "https://hellodanang.vn/topAZ/quan-hai-san-tai-da-nang",
          "domain": "hellodanang.vn",
          "type": "organic"
        },
        {
          "position": 3,
          "title": "E xin review quán hải sản ngon ở Đà nẵng với ạ.",
          "url": "https://www.facebook.com/groups/306716320482601/posts/1449744309513124/",
          "domain": "www.facebook.com",
          "type": "organic"
        },
        {
          "position": 4,
          "title": "10 Nhà Hàng Hải Sản Bạn Phải Thử Khi Đến Đà Nẵng",
          "url": "https://www.pullman-danang.com/vi/kham-pha/am-thuc/nha-hang-hai-san-da-nang/",
          "domain": "www.pullman-danang.com",
          "type": "organic"
        },
        {
          "position": 5,
          "title": "10 Quán hải sản Đà Nẵng tươi ngon, từ bình dân đến sang ...",
          "url": "https://danangthanhkhe.aeonmall-vietnam.com/vi/kham-pha-da-thanh/quan-hai-san-da-nang.html",
          "domain": "danangthanhkhe.aeonmall-vietnam.com",
          "type": "organic"
        },
        {
          "position": 6,
          "title": "Top 10+ Quán hải sản ngon ở Mỹ Khê Đà Nẵng tươi sống ...",
          "url": "https://pasgo.vn/kham-pha/kien-giang/top-cac-quan-hai-san-ngon-o-my-khe-da-nang-1778",
          "domain": "pasgo.vn",
          "type": "organic"
        },
        {
          "position": 7,
          "title": "15+ quán hải sản Đà Nẵng tươi ngon, giá rẻ bình dân",
          "url": "https://sstay.vn/blog/hai-san-da-nang",
          "domain": "sstay.vn",
          "type": "organic"
        },
        {
          "position": 8,
          "title": "Top 15 quán nhậu Đà Nẵng giá rẻ bình dân hải sản tươi ...",
          "url": "https://duonggiahotel.vn/quan-nhau-da-nang/",
          "domain": "duonggiahotel.vn",
          "type": "organic"
        },
        {
          "position": 9,
          "title": "4 quán hải sản đông khách nhất ở Đà Nẵng, cả nhà lưu lại có ...",
          "url": "https://www.facebook.com/dacsandananghanigo/videos/4-qu%C3%A1n-h%E1%BA%A3i-s%E1%BA%A3n-%C4%91%C3%B4ng-kh%C3%A1ch-nh%E1%BA%A5t-%E1%BB%9F-%C4%91%C3%A0-n%E1%BA%B5ng-c%E1%BA%A3-nh%C3%A0-l%C6%B0u-l%E1%BA%A1i-c%C3%B3-d%E1%BB%8Bp-kh%C3%A1m-ph%C3%A1-%E1%BA%A9m-th%E1%BB%B1c-/965666872055121/",
          "domain": "www.facebook.com",
          "type": "organic"
        }
      ],
      "people_also_ask": [],
      "related_searches": [
        "Hải sản Thời Cổ",
        "Hải sản Năm Đảnh",
        "Hải sản Mộc quán",
        "Hải Sản Gành Bàng",
        "Quán Eo Biển",
        "Hải Sản Bé Anh 1 – Quán hải...",
        "Mỹ Hạnh Seafood – Quán hải...",
        "Nhà hàng hải sản Đà Nẵng",
        "Review quán hải sản ngon Đà Nẵng",
        "Quán hải sản ngon ở Sơn Trà, Đà Nẵng"
      ],
      "snippets": [],
      "keyword_cluster": [
        "quán hải sản ngon Đà Nẵng",
        "hải sản giá rẻ",
        "gần biển Mỹ Khê",
        "Sơn Trà",
        "quán nhậu Đà Nẵng",
        "buffet hải sản"
      ],
      "content_angle": [
        "review",
        "top list",
        "trải nghiệm",
        "giá rẻ",
        "du lịch ăn uống"
      ],
      "intent": [
        "ăn nhậu",
        "du lịch",
        "gia đình",
        "buffet",
        "hải sản tươi sống"
      ],
      "competitor_pattern": [
        "Pasgo",
        "Tripadvisor",
        "Blog du lịch SEO",
        "Facebook group",
        "Local listing / directory"
      ]
    },
    "final_report": "Query: nhà hàng quán nhậu hải sản Đà Nẵng\nBusiness: moc quan nha trang\nSuggestions: 41\nSERP urls: 9\nFB posts: 11\nFB comments: 36\n",
    "suggestions_tagged": {
      "budget": [
        "nhà hàng quán nhậu hải sản đà nẵng giá bao nhiêu",
        "nhà hàng quán nhậu hải sản đà nẵng cho trẻ em",
        "nhà hàng quán nhậu hải sản đà nẵng giá",
        "nhà hàng quán nhậu hải sản đà nẵng rẻ nhất",
        "nhà hàng quán nhậu hải sản đà nẵng rẻ",
        "nhà hàng quán nhậu hải sản đà nẵng rẻ ngon",
        "nhà hàng quán nhậu hải sản đà nẵng giá rẻ",
        "nhà hàng quán nhậu hải sản đà nẵng giá vé",
        "nhà hàng quán nhậu hải sản đà nẵng ngon rẻ"
      ],
      "location": [
        "nhà hàng quán nhậu hải sản đà nẵng gần đây",
        "nhà hàng quán nhậu hải sản đà nẵng ở đà nẵng",
        "nhà hàng quán nhậu hải sản đà nẵng ở sài gòn",
        "nhà hàng quán nhậu hải sản đà nẵng tại đà nẵng",
        "nhà hàng quán nhậu hải sản đà nẵng gần biển",
        "nhà hàng quán nhậu hải sản đà nẵng gần nhất",
        "nhà hàng quán nhậu hải sản đà nẵng ở nha trang",
        "nhà hàng quán nhậu hải sản đà nẵng ở đâu ngon",
        "nhà hàng quán nhậu hải sản đà nẵng tại nha trang"
      ],
      "food": [
        "nhà hàng quán nhậu hải sản đà nẵng 5 sao",
        "nhà hàng quán nhậu hải sản đà nẵng nào đẹp",
        "nhà hàng quán nhậu hải sản đà nẵng ngon nhất",
        "nhà hàng quán nhậu hải sản đà nẵng a lưới",
        "nhà hàng quán nhậu hải sản đà nẵng cho bé",
        "nhà hàng quán nhậu hải sản đà nẵng tuy hòa",
        "nhà hàng quán nhậu hải sản đà nẵng 500k",
        "nhà hàng quán nhậu hải sản đà nẵng chotot",
        "nhà hàng quán nhậu hải sản đà nẵng đẹp nhất",
        "nhà hàng quán nhậu hải sản đà nẵng 30k",
        "nhà hàng quán nhậu hải sản đà nẵng reviews",
        "nhà hàng quán nhậu hải sản đà nẵng cho thuê",
        "nhà hàng quán nhậu hải sản đà nẵng 100k",
        "nhà hàng quán nhậu hải sản đà nẵng nổi tiếng",
        "nhà hàng quán nhậu hải sản đà nẵng review",
        "nhà hàng quán nhậu hải sản đà nẵng 30/4",
        "nhà hàng quán nhậu hải sản đà nẵng tuyển dụng",
        "nhà hàng quán nhậu hải sản đà nẵng 1990",
        "nhà hàng quán nhậu hải sản đà nẵng ngon",
        "nhà hàng quán nhậu hải sản đà nẵng nào ngon",
        "nhà hàng quán nhậu hải sản đà nẵng 1980",
        "nhà hàng quán nhậu hải sản đà nẵng a-z",
        "nhà hàng quán nhậu hải sản đà nẵng 199k"
      ],
      "experience": [],
      "family": [],
      "question": [],
      "other": []
    },
    "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
    "fb_brand": {
      "page_info": {
        "title": "Facebook",
        "followers": "43K",
        "following": ""
      },
      "intro": "Facebook\nFacebook\nActive Status indicator\nHải sản Mộc quán Đà Nẵng\n43K\nfollowers\n•\nfollowing\nPosts\nAbout\nReels\nPhotos\nMore\nPosts\nAbout\nReels\nPhotos\nHải sản Mộc quán Đà Nẵng\nIntro\n⏰ Giờ mở cửa: 10:30AM – 23:45PM\n(Nhận order cuối lúc 22:30PM)\n📍 Cơ sở 1: 26 Tô Hiến Thành, Sơn Trà, Đà Nẵng\nHotline Đà Nẵng: 0964 531 153 – 0905 665 058\n📍 Cơ sở 2: 74–76 Hồng Bàng, Tân Lập, Nha Trang\nHotline Nha Trang: 0934 981 180\nPage\n· Seafood restaurant\n26 Tô Hiến Thành, Da Nang, Vietnam\n090 566 50 58\n+84 90 566 50 58\nmocseafood@facebook.com\nhaisanmocquandanang\nmocseafood_dn\nhaisanmocquan\nmocseafood_dn\n다낭목해산물식당\nmocseafood.com\nguide.michelin.com/vn/en/da-nang-region/da-nang_2984390/restaurant/moc\ntripadvisor.com/Restaurant_Review-g298085-d16891168-Reviews-M_c_Seafood_Restaurant-Da_Nang.html\nOpen now\nDelivery · Takeaway · Dine in…\nPrice range · ££\n94% recommend (79 reviews)\n﻿\nPhotos\nSee All Photos\nPrivacy\n·\nTerms\n·\nAdvertising\n·\nAd choices\n·\nCookies\n·\nMore\nOnline status indicator\nActive\nHải sản Mộc quán Đà Nẵng\nis at\nHải sản Mộc quán Đà Nẵng\n.\n1d\n·\nDa Nang\n·\nShared with Public\nMANG TRỌN HƯƠNG VỊ MỘC VỀ TẬN NHÀ – CHUẨN VỊ NHƯ THƯỞNG THỨC TẠI QUÁN!\nDù là một buổi tối quây quần ấm cúng tại gia, một buổi trưa bận rộn tại văn phòng, hay đơn giản là hôm nay bạn... lười ra đường, thì những món ngon từ bếp nhà Mộc vẫn luôn sẵn sàng phục vụ tận nhà cho cả nhà mình!\nChất lượng không đổi – Tâm huyết vẹn nguyên. Mộc hiểu rằng, trải nghiệm ẩm thực tại nhà cũng cần phải hoàn hảo. Dù là đơn hàng giao đi hay mang",
á mọi giới hạn hương vị!\n—---------------------\nMICHELIN Selected 2026 – For the second consecutive year, the passion of Mộc's chefs is honored!\nThere are glittering achievements marked by titles. But for those who keep the flame of the kitchen burning, the greatest glory is the satisfied nod of the diners when the dish first touches their palate.\nBehind every culinary masterpiece lies thousands of hours of tireless effort in the kitchen. It's the meticulous selection of ingredients to the absolute precision of each flame. More than just an award, this is proof of the talent, dedication, and \"vision\" of the Mộc Kitchen Team – artists who pour their hearts into every flavor.\nThe title belongs to the kitchen, but the success belongs to the customer experience. Mộc expresses its gratitude to the golden hands of the Kitchen Team and the restaurant staff, and extends its deepest thanks to our valued customers who have always trusted and supported us.\nMộc would like to thank the golden hands of our Kitchen Team and restaurant staff, and extend our deepest thanks to our esteemed customers for their continued trust and support. MICHELIN isn't the final destination; it's a launching pad for Mộc's chefs to continue pushing the boundaries of flavor!\n---------\n𝐌𝐨̣̂𝐜 𝐒𝐞𝐚𝐟𝐨𝐨𝐝 𝐑𝐞𝐬𝐭𝐚𝐮𝐫𝐚𝐧𝐭\nCS1 (Đà Nẵng): 26 Tô Hiến Thành, Sơn Trà, Đà Nẵng\nHotline: 0905 665 058 - 0964 531 153\nCS2 (Nha Trang): 74 - 76 Hồng Bàng, Tân Lập, Nha Trang\nHotline: 0934 981 180\nGiờ phục vụ: 10:30 AM – 23:45 PM (22:30 bếp đóng)"
    },
    {
      "created_at": "2026-06-20T12:24:35.935806",
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "id": 15,
      "attachments": [
        "https://scontent.fdad3-6.fna.fbcdn.net/v/t51.82787-10/724720557_18173444443418097_4870339857583484788_n.jpg?stp=dst-jpg_tt6&cstp=mx1440x2560&ctp=s960x960&_nc_cat=100&ccb=1-7&_nc_sid=5fad0e&_nc_ohc=LuDZ6hcHilYQ7kNvwGhrKkP&_nc_oc=AdqJYeSqRpQqbFMBxoFgYXtgI8bCf6Kmq3peXPEeDTMgDEJLvF3nV67GWMv9gkNkLiQ&_nc_zt=23&_nc_ht=scontent.fdad3-6.fna&_nc_gid=GL6zMm8qyH97IJJysN0M7A&_nc_ss=7b289&oh=00_Af_WWIeZjO9qmGJv34FCRkXpcOGjoTGrMnRESKTWorElSw&oe=6A3C0E3E",
        "https://scontent.fdad3-6.fna.fbcdn.net/v/t39.30808-6/719622187_1007272521688285_8123410453609298804_n.jpg?stp=dst-jpg_tt6&cstp=mx2048x2048&ctp=s590x590&_nc_cat=108&ccb=1-7&_nc_sid=127cfc&_nc_ohc=N2E3pIcEoRgQ7kNvwF5ceez&_nc_oc=AdqofSmD7fWzctkUNI2ZC4UzlkjZhakAba52zE_7Pm4tPOe-Kri6y-4By_TVDV8FfwI&_nc_zt=23&_nc_ht=scontent.fdad3-6.fna&_nc_gid=lrru3yif4a5OLdnXWwZCPw&_nc_ss=7b289&oh=00_Af-b9p2pZv38NvCqQem2SMi8BBkQKxc4wWv_LdpP2RbL_Q&oe=6A3C124A"
      ],
Moc to this proud milestone.\nThe entire Kitchen Team: always maintaining the flame of enthusiasm and that never dies out.\nRestaurant Team: their relentless efforts, always thoughtful, attentive, and passionate in every gesture, always wholeheartedly caring for and cherishing every customer experience at Moc.\nBeing honored by MICHELIN is not the final destination. This is the launching pad for Mộc to continue pushing boundaries, constantly improving and upgrading \"Mộc\" to a higher level in the future\nHải sản Mộc quán Nha Trang\n#MICHELINSTAR26\n#MICHELINGUIDEVN\n#HAISANMOCQUAN\n#MOCDANANG\n#MOCNHATRANG"
    },
    {
      "created_at": "2026-06-20T12:24:35.935811",
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "id": 18,
      "attachments": [
        "https://scontent.fdad3-6.fna.fbcdn.net/v/t39.30808-6/716922684_1004027968679407_4324716177190327212_n.jpg?stp=dst-jpg_tt6&cstp=mx2048x2048&ctp=s590x590&_nc_cat=111&ccb=1-7&_nc_sid=833d8c&_nc_ohc=p_86Vl7qxdEQ7kNvwHQP1SZ&_nc_oc=AdrXZvLKlZoMKLnUG2qFhJHv_zDnZhmFOYPUkx4-g5w0HF16zcmHaTTs0NfRzSUjou4&_nc_zt=23&_nc_ht=scontent.fdad3-6.fna&_nc_gid=lrru3yif4a5OLdnXWwZCPw&_nc_ss=7b289&oh=00_Af_f9ByneYCR9TgisR6wr3F5tzHI2JrP78iRcMlYKakCUA&oe=6A3C061F",
        "https://scontent.fdad3-6.fna.fbcdn.net/v/t39.30808-6/709960874_1004027965346074_8291711181017998670_n.jpg?stp=dst-jpg_tt6&cstp=mx1280x800&ctp=s590x590&_nc_cat=103&ccb=1-7&_nc_sid=833d8c&_nc_ohc=W1I_0FSV2hYQ7kNvwFC5PnJ&_nc_oc=Adr7QQpPzgXwG9UmbeZx3P1Hnx8EIi9uIJenF5T-4UBFW2Uum8uZz6M6-gv1HTfBAWc&_nc_zt=23&_nc_ht=scontent.fdad3-6.fna&_nc_gid=lrru3yif4a5OLdnXWwZCPw&_nc_ss=7b289&oh=00_Af_367VKpW-Xuo7H_YlC1Zd1vfYkP1HKGwx1RftakyNXXw&oe=6A3BF878"
      ],
      "content": "THƯỞNG THỨC DIFF 2026 TRỌN VẸN – NẠP NĂNG LƯỢNG TẠI MỘC QUÁN, KHÔNG LO CẤM ĐƯỜNG\nĐêm khai mạc Lễ hội Pháo hoa Quốc tế Đà Nẵng (DIFF 2026) chính thức bùng nổ vào hôm nay (30/05)! Để chuyến đi chơi, xem pháo hoa của bạn và gia đình không bị gián đoạn bởi các tuyến đường phân luồng, Mộc Quán đã cập nhật nhanh lộ trình \"vàng\" giúp bạn di chuyển cực kỳ thuận lợi đến quán ăn gia đình, nạp năng lượng trước hoặc sau giờ diễn ra lễ hội.\nĐịa chỉ của Mộc: 26 Tô Hiến Thành, Sơn Trà (Khu vực gần biển Mỹ Khê, đường xá thông thoáng và nằm ngoài vùng cấm xe máy).\nTÓM TẮT CÁC TUYẾN ĐƯỜNG CẤM HÔM NAY (Cần lưu ý)\nĐể tránh đi nhầm vào vùng lõi
? Head straight to Mộc Quán—we’ve got the ultimate \"12-Way Shrimp Feast\" waiting to shake things up for you and your squad! What makes this menu so addictive?\nIt’s all about our COLLECTION OF SIGNATURE SAUCES, masterfully crafted by our head chef. We know every foodie has a unique taste, so we’ve designed 12 distinct flavor profiles just for you:\nFor the rich & creamy lovers: Our decadent, velvety sauces will awaken your senses.\nFor those seeking an explosion of heat: Our bold, signature spicy sauces are so addictive, you won’t be able to stop at just one bite.\nFor the flavor purists: We have delicate preparations that perfectly highlight the natural sweetness and snap of our fresh, premium shrimp.\nEven the pickiest eaters will find their \"soulmate\" dish here. Fresh, succulent shrimp drenched in rich, flavorful sauce—one bite is all it takes to get hooked on that authentic taste of the ocean.\nNo need to overthink your dinner plans. Get pampered at Mộc Quán!\nSkip the home cooking tonight, gather your crew, and head over to 26 Tô Hiến Thành to conquer our 12-way menu!\n—-----------------------------------------------\n𝐌𝐨̣̂𝐜 𝐒𝐞𝐚𝐟𝐨𝐨𝐝 𝐑𝐞𝐬𝐭𝐚𝐮𝐫𝐚𝐧𝐭\nCS1 (Đà Nẵng): 26 Tô Hiến Thành, Sơn Trà, Đà Nẵng\nHotline: 0905 665 058 - 0964 531 153\nCS2 (Nha Trang): 74 - 76 Hồng Bàng, Tân Lập, Nha Trang\nHotline: 0934 981 180\nGiờ phục vụ: 10:30 AM – 23:45 PM (22:30 bếp đóng)\n#MocQuan\n#MocSeafood\n#HaiSanTuoiSong\n#ReviewAnUong\n#DaNang"
    },
    {
      "created_at": "2026-06-20T12:24:35.935817",
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "id": 22,
      "attachments": [
        "https://scontent.fdad3-6.fna.fbcdn.net/v/t39.30808-6/710746367_997672939314910_7481644398581130844_n.jpg?stp=dst-jpg_tt6&cstp=mx2048x2048&ctp=s590x590&_nc_cat=103&ccb=1-7&_nc_sid=127cfc&_nc_ohc=uZOfVAz13a8Q7kNvwF5wwu-&_nc_oc=AdpMKoHKKSgKL3qfO1P22-wR_MBwsZKbEg2sIcTMYHA3B35OiJ3DIaSla8ErIDXhewc&_nc_zt=23&_nc_ht=scontent.fdad3-6.fna&_nc_gid=lrru3yif4a5OLdnXWwZCPw&_nc_ss=7b289&oh=00_Af_YDYgu-z7hdBCBGlEZHHyMrPOsb3gD-MQ9VsowKiY-Tw&oe=6A3C0833",
        "https://scontent.fdad3-6.fna.fbcdn.net/v/t39.30808-6/708088682_995162136232657_7824093461528913891_n.jpg?stp=dst-jpg_tt6&cstp=mx2048x1365&ctp=s590x590&_nc_cat=107&ccb=1-7&_nc_sid=127cfc&_nc_ohc=4fLKSDFJ3bgQ7kNvwHXAagg&_nc_oc=Adpo8v8lD4tdg3mvJyHWnzi4VzHm4DMSEZ2BGJkRijyoNiWvm5aeJej9BlWYnGoFB5Y&_nc_zt=23&_nc_ht=scontent.fdad3-6.fna&_nc_gid=lrru3yif4a5OLdnXWwZCPw&_nc_ss=7b289&oh=00_Af-ohF7VBqkYUlm9Cj6rUN0rOHKdVlYfnCHbmRccLtqwCA&oe=6A3C09DB",
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "created_at": "2026-06-20T12:24:35.923980"
    },
    {
      "time": "2 weeks ago",
      "id": 72,
      "author": "Kuen Gen",
      "replies": [],
      "comment": "Quá tuỵt vời",
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "created_at": "2026-06-20T12:24:35.923981"
    },
    {
      "time": "2 weeks ago",
      "id": 73,
      "author": "Kuen Gen",
      "replies": [],
      "comment": "Kuen Gen",
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "created_at": "2026-06-20T12:24:35.923982"
    },
    {
      "time": "4 hours ago",
      "id": 74,
      "author": "Phan Thị Hà",
      "replies": [
        "Hải sản Mộc quán Đà Nẵng replied · 1 reply 4h"
      ],
      "comment": "Cho e đặt bàn đêm 27/6 ạ",
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "created_at": "2026-06-20T12:24:35.923982"
    },
    {
      "time": "Không rõ",
      "id": 75,
      "author": "Ẩn danh",
      "replies": [],
      "comment": "MANG TRỌN HƯƠNG VỊ MỘC VỀ TẬN NHÀ – CHUẨN VỊ NHƯ THƯỞNG THỨC TẠI QUÁN!Dù là một buổi tối quây quần ấm cúng tại gia, một buổi trưa bận rộn tại văn phòng, hay đơn giản là hôm nay bạn... lười ra đường, thì những món ngon từ bếp nhà Mộc vẫn luôn sẵn sàng phục vụ tận nhà cho cả nhà mình!Chất lượng không đổi – Tâm huyết vẹn nguyên. Mộc hiểu rằng, trải nghiệm ẩm thực tại nhà cũng cần phải hoàn hảo. Dù là đơn hàng giao đi hay mang về, đội ngũ đầu bếp của chúng tôi vẫn giữ vững những tiêu chí khắt khe nhất:- Nguồn nguyên liệu hải sản đầu vào luôn tươi rói, chất lượng nhất.- Tính nhất quán trong phong cách chế biến, đảm bảo món ăn giữ được trọn vẹn hương vị đặc trưng.- Đóng gói cẩn thận, chỉn chu để món ăn đến tay bạn vẫn giữ được độ nóng hổi và hấp dẫn.Linh hoạt lựa chọn – Chiều lòng thực khách:- Giao hàng tận nơi: Chỉ cần xem menu, chọn món và nhắn Mộc. Đội ngũ giao hàng sẽ mang những hương vị tuyệt vời nhất đến tận cửa nhà bạn.- Đến lấy trực tiếp (Take-away): Bạn có thể gọi điện đặt trước và ghé quán nhận món nhanh chóng mà không cần phải chờ đợi.Cơm nhà hôm nay chưa nấu, hay bất chợt thèm hương vị hải sản đậm đà quen thuộc? Gian bếp của Mộc đã đỏ lửa, sẵn sàng mang đến cho bạn một bữa ăn xứng đáng và trọn vẹn nhất!Inbox ngay cho Fanpage hoặc gọi Hotline để đặt món nhé!----------BRING THE AUTHENTIC TASTE OF MỘC RIGHT TO YOUR HOME – JUST AS DELICIOUS AS DINING IN!Whether it's a cozy evening gathering at home, a busy lunch break at the office, or simply because today you are... feeling too lazy to go out, the delicious dishes from Mộc's kitchen are always ready to serve you!Uncompromising Quality – Unwavering Dedication.Mộc understands that your dining experience at home needs to be just as perfect. Whether it is a delivery or take-away order, our team of chefs always upholds the strictest standards:- Sourcing only the freshest and highest-quality seafood ingredients.-Consistency in our cooking style, ensuring each dish retains its full signature flavor.-Careful and meticulous packaging so your food arrives piping hot and visually appetizing.Flexible Options – Catering to Every Diner:-Door-to-door Delivery: Simply browse our menu, pick your dishes, and message Mộc. Our delivery team will bring the most amazing flavors right to your doorstep.-Direct Pickup (Take-away): Give us a call to order in advance, then drop by the restaurant to quickly pick up your food without the wait.Haven't cooked today, or suddenly craving that familiar, rich seafood flavor? Mộc's kitchen is already fired up and ready to bring you a truly fulfilling and well-deserved meal!-----𝐌𝐨̣̂𝐜 𝐒𝐞𝐚𝐟𝐨𝐨𝐝 𝐑𝐞𝐬𝐭𝐚𝐮𝐫𝐚𝐧𝐭CS1 (Đà Nẵng): 26 Tô Hiến Thành, Sơn Trà, Đà Nẵng�Hotline: 0905 665 058 - 0964 531 153CS2 (Nha Trang): 74 - 76 Hồng Bàng, Tân Lập, Nha Trang�Hotline: 0934 981 180Giờ phục vụ: 10:30 AM – 23:45 PM (22:30 bếp đóng)#MocQuan#MocSeafood#HaiSanTuoiSong#DaNang",
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "created_at": "2026-06-20T12:24:35.923983"
    },
    {
      "time": "Không rõ",
      "id": 76,
      "author": "Ẩn danh",
      "replies": [
        "Hải sản Mộc quán Đà Nẵng replied · 1 reply 1h"
      ],
      "comment": "Ib chị nhé",
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "created_at": "2026-06-20T12:24:35.923983"
    },
    {
      "time": "21 hours ago",
      "id": 77,
      "author": "Hoàng Mai Trần",
      "replies": [
        "Hải sản Mộc quán Đà Nẵng replied · 1 reply"
      ],
      "comment": "Ib chị",
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "created_at": "2026-06-20T12:24:35.923984"
    },
    {
      "time": "Không rõ",
      "id": 78,
      "author": "Ẩn danh",
      "replies": [],
      "comment": "MICHELIN Selected 2026 – ngọn lửa đam mê của các Đầu bếp nhà Mộc lại một lần nữa được vinh danh!Có những thành công lấp lánh bởi danh hiệu. Nhưng với người giữ lửa gian bếp, vinh quang rực rỡ nhất chính là cái gật đầu mãn nguyện của thực khách khi món ăn vừa chạm vị.Phía sau mỗi tuyệt tác trên bàn tiệc là hàng ngàn giờ bền bỉ sau gian bếp. Là sự khắt khe từ khâu tinh tuyển nguyên liệu đến độ chính xác tuyệt đối của từng ngọn lửa. Hơn cả một giải thưởng, đây là minh chứng cho tài hoa, sự tận hiến và cái \"tầm\" của Đội ngũ Bếp nhà Mộc – những nghệ sĩ luôn gửi gắm trọn vẹn tâm hồn vào từng hương vị.Danh hiệu thuộc về bếp, nhưng thành công thuộc về trải nghiệm của khách hàng. Mộc xin tri ân những đôi tay vàng của Đội ngũ Bếp, đội ngũ nhà hàng và gửi lời cảm ơn sâu sắc nhất đến Quý thực khách đã luôn tin yêu, đồng hành.MICHELIN không phải đích đến cuối cùng, đây là bệ phóng để những người làm bếp nhà Mộc tiếp tục bứt phá mọi giới hạn hương vị!—---------------------MICHELIN Selected 2026 – For the second consecutive year, the passion of Mộc's chefs is honored!There are glittering achievements marked by titles. But for those who keep the flame of the kitchen burning, the greatest glory is the satisfied nod of the diners when the dish first touches their palate.Behind every culinary masterpiece lies thousands of hours of tireless effort in the kitchen. It's the meticulous selection of ingredients to the absolute precision of each flame. More than just an award, this is proof of the talent, dedication, and \"vision\" of the Mộc Kitchen Team – artists who pour their hearts into every flavor.The title belongs to the kitchen, but the success belongs to the customer experience. Mộc expresses its gratitude to the golden hands of the Kitchen Team and the restaurant staff, and extends its deepest thanks to our valued customers who have always trusted and supported us.Mộc would like to thank the golden hands of our Kitchen Team and restaurant staff, and extend our deepest thanks to our esteemed customers for their continued trust and support. MICHELIN isn't the final destination; it's a launching pad for Mộc's chefs to continue pushing the boundaries of flavor!---------𝐌𝐨̣̂𝐜 𝐒𝐞𝐚𝐟𝐨𝐨𝐝 𝐑𝐞𝐬𝐭𝐚𝐮𝐫𝐚𝐧𝐭CS1 (Đà Nẵng): 26 Tô Hiến Thành, Sơn Trà, Đà NẵngHotline: 0905 665 058 - 0964 531 153CS2 (Nha Trang): 74 - 76 Hồng Bàng, Tân Lập, Nha TrangHotline: 0934 981 180Giờ phục vụ: 10:30 AM – 23:45 PM (22:30 bếp đóng)",
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "created_at": "2026-06-20T12:24:35.923984"
    },
    {
      "time": "18 hours ago",
      "id": 79,
      "author": "Phan Mỹ Linh",
      "replies": [
        "Hải sản Mộc quán Đà Nẵng replied · 1 reply"
      ],
      "comment": "Ib m đặt bàn với ạ",
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "created_at": "2026-06-20T12:24:35.923984"
    },
    {
      "time": "3 days ago",
      "id": 80,
      "author": "Thúy Lã",
      "replies": [
        "Hải sản Mộc quán Đà Nẵng replied · 1 reply"
      ],
      "comment": "Mộc rất xứng đáng. Rất ấn tượng",
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "created_at": "2026-06-20T12:24:35.923985"
    },
    {
      "time": "Không rõ",
      "id": 81,
      "author": "Ẩn danh",
      "replies": [],
      "comment": "Em muốn đặt bàn cho tối nay 16 người ạ. Em goii hotline toàn thuê bao",
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "created_at": "2026-06-20T12:24:35.923985"
    },
    {
      "time": "Không rõ",
      "id": 82,
      "author": "Ẩn danh",
      "replies": [],
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "created_at": "2026-06-20T12:24:35.923986"
    },
    {
      "time": "21 hours ago",
      "id": 83,
      "author": "Nguyễn Thanh Hoa",
      "replies": [],
      "comment": "e muốn đặt bàn ạ",
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "created_at": "2026-06-20T12:24:35.923986"
    },
    {
      "time": "Không rõ",
      "id": 84,
      "author": "Ẩn danh",
      "replies": [
        "Hải sản Mộc quán Đà Nẵng replied · 1 reply"
      ],
      "comment": "C muốn đặt bản",
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "created_at": "2026-06-20T12:24:35.923986"
    },
    {
      "time": "4 days ago",
      "id": 85,
      "author": "Ngô Thanh Mai",
      "replies": [
        "Hải sản Mộc quán Đà Nẵng replied · 1 reply"
      ],
      "comment": "Bạn ơi. Check ib cho mình đặt bàn với ạ",
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "created_at": "2026-06-20T12:24:35.923987"
    },
    {
      "time": "Không rõ",
      "id": 86,
      "author": "Ẩn danh",
      "replies": [],
      "comment": "[THÔNG BÁO] HỆ THỐNG MỘC SEAFOOD CHỈ CÓ DUY NHẤT 02 CƠ SỞ CHÍNH THỨC!Thực khách thân mến,Để tạo ra một trải nghiệm ẩm thực trọn vẹn, đội ngũ nhà Mộc luôn đặt ra những tiêu chuẩn khắt khe nhất: từ nguồn nguyên liệu hải sản tươi rói, tính nhất quán trong phong cách chế biến, cho đến không gian thưởng thức ngập tràn \"vibe\" biển cả.Chính vì vậy, để bảo vệ quyền lợi của bạn và đảm bảo mỗi bữa ăn đều xứng đáng với sự tin yêu dành cho Mộc, chúng tôi xin đính chính thông tin chính thức: Hiện tại, Mộc Seafood CHỈ CÓ 02 CƠ SỞ DUY NHẤT tại Đà Nẵng và Nha Trang.01 cơ sở Mộc Seafood Đà Nẵng:Địa chỉ: 26 Tô Hiến Thành, An Hải, Đà NẵngHotline: 0964 531 153 – 0905 665 05801 cơ sở Mộc Seafood Nha Trang:Địa chỉ: 74-76 Hồng Bàng, Nha Trang, Khánh HoàHotline: 0934 981 180LƯU Ý: Ngoài 2 địa chỉ nêu trên, Mộc Seafood KHÔNG CÓ bất kỳ chi nhánh hay địa điểm nào khác. Mọi thông tin khác đều là giả mạo.Quý khách vui lòng kiểm tra kỹ thông tin, lưu lại địa chỉ hoặc gọi trực tiếp vào Hotline của chúng tôi để đặt bàn. Đội ngũ bếp và nhân viên nhà Mộc luôn sẵn sàng đón tiếp và mang đến cho bạn những hương vị tuyệt vời nhất tại đúng \"nhà\" của mình!-----[IMPORTANT ANNOUNCEMENT] MỘC SEAFOOD HAS ONLY 2 OFFICIAL LOCATIONS!To ensure you always experience our signature fresh seafood, consistent culinary quality, and dedicated service, please be informed that Mộc Seafood currently operates at ONLY 2 LOCATIONS:Mộc Seafood Da Nang: 26 To Hien Thanh Street, An Hai Ward, Da Nang(Hotline: 0964 531 153 – 0905 665 058)Mộc Seafood Nha Trang: 74-76 Hong Bang, Nha Trang, Khanh Hoa(Hotline: 0934 981 180)Apart from these 2 locations, Mộc Seafood has no other branches. Please kindly verify our official information before making a reservation to avoid confusion with fake addresses. We look forward to welcoming you!#MocSeafood#MocSeafoodDaNang#MocSeafoodNhaTrang",
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "created_at": "2026-06-20T12:24:35.923987"
    },
    {
      "time": "Không rõ",
      "id": 87,
      "author": "Ẩn danh",
      "replies": [
        "Hải sản Mộc quán Đà Nẵng replied · 1 reply"
      ],
      "comment": "Mình muốn đặt bàn tối nay mà gọi điện cho nhà hàng mãi k đc ạ",
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "created_at": "2026-06-20T12:24:35.923988"
    },
    {
      "time": "Không rõ",
      "id": 88,
      "author": "Ẩn danh",
      "replies": [],
      "comment": "HÀNH TRÌNH CỦA SỰ TẬN TÂM – MICHELIN SELECTED 2026 NĂM THỨ 2 LIÊN TIẾPNgôi sao thắp sáng từ những ngọn lửa không bao giờ tắt nơi gian bếp nhà Mộc. Nhìn lại chặng đường tiếp tục được xướng tên trên bản đồ ẩm thực danh giá MICHELIN. Mộc hiểu, vinh quang này không đến từ phép màu. Nó được đánh đổi bằng mồ hôi, tâm huyết và những nỗ lực không ngừng nghỉ của đội ngũ nhân viên MộcHơn cả một danh hiệu, đó là câu chuyện về sự kiên trì - \"có công mài sắt, có ngày nên kim\"\"Có những thành công được đo bằng danh hiệu.Nhưng có những thành công được đo bằng sự tin yêu của khách hàng\"Đây không chỉ là niềm tự hào của riêng Mộc, mà còn là sự ghi nhận cho những nỗ lực không ngừng nghỉ của toàn thể đội ngũ nhân viên, những người luôn tận tâm trong từng công đoạn phục vụ, từ khâu lựa chọn nguyên liệu, chế biến món ăn đến nâng cao chất lượng phục vụ trải nghiệm của mỗi thực kháchMộc xin gửi lời cảm ơn chân thành đến Quý khách hàng và Quý đối tác đã luôn tin tưởng, yêu mến, đồng hành và là thước đo công tâm nhất của Mộc trong suốt thời gian qua. Sự ủng hộ của mọi người chính là động lực để Mộc không ngừng hoàn thiện và phát triển hơn nữa trong chặng đường phía trướcĐặc biệt, Mộc xin gửi lời tri ân sâu sắc đến toàn thể đội ngũ nhân viên nhà hàng -  Cảm ơn sự tận tâm, trách nhiệm, tinh thần đoàn kết và những nỗ lực thầm lặng của mỗi thành viên đã góp phần tạo nên những trải nghiệm trọn vẹn cho khách hàng và đưa Mộc chạm đến cột mốc đáng tự hào này.Toàn thể Đội ngũ Bếp: luôn giữ được ngọn lửa nhiệt huyết và sự tận tâm chưa bao giờ tắtĐội ngũ Nhà hàng: sự nỗ lực không ngừng, luôn chu đáo, tận tình và tâm huyết trong từng cử chỉ, luôn hết lòng chăm sóc, nâng niu trọn vẹn từng trải nghiệm của khách hàng tại Mộc.Được MICHELIN vinh danh không phải là đích đến cuối cùng. Đây là bệ phóng để Mộc tiếp tục bứt phá giới hạn, không ngừng hoàn thiện và nâng cấp \"Mộc\" lên một tầm cao mới hơn trong tương lai-----A JOURNEY OF DEDICATION – MICHELIN SELECTED 2026 FOR THE SECOND CONSECUTIVE YEARA star illuminated by the never-extinguishing flames in Moc's kitchen. Looking back on our journey to continue being recognized on the prestigious MICHELIN culinary map, Moc understands that this glory didn't come from magic. It was earned through the sweat, dedication, and tireless efforts of the Mộc teamMore than just a title, it's a story of perseverance – \"hard work pays off\"\"Some successes are measured by titles.But some successes are measured by the trust and love of our customers.\"This is not only Mộc's pride, but also a recognition of the tireless efforts of our entire team, who are always dedicated to every step of the service process, from selecting ingredients and preparing dishes to enhancing the quality of service and the experience of each dinerMộc would like to express our sincere gratitude to our valued customers and partners who have always trusted, loved, and supported us, and who have been the fairest measure of Mộc's success throughout this time. Everyone's support is the driving force behind Moc's continuous improvement and further development in the journey aheadIn particular, Moc would like to express its deepest gratitude to the entire restaurant staff - Thank you for your dedication, responsibility, team spirit, and the silent efforts of each member that have contributed to creating complete experiences for customers and bringing Moc to this proud milestone.The entire Kitchen Team: always maintaining the flame of enthusiasm and that never dies out.Restaurant Team: their relentless efforts, always thoughtful, attentive, and passionate in every gesture, always wholeheartedly caring for and cherishing every customer experience at Moc.Being honored by MICHELIN is not the final destination. This is the launching pad for Mộc to continue pushing boundaries, constantly improving and upgrading \"Mộc\" to a higher level in the futureHải sản Mộc quán Nha Trang#MICHELINSTAR26#MICHELINGUIDEVN#HAISANMOCQUAN#MOCDANANG#MOCNHATRANG",
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "created_at": "2026-06-20T12:24:35.923988"
    },
    {
      "time": "2 weeks ago",
      "id": 89,
      "author": "Đặng Thị Ngọc Duyên",
      "replies": [],
      "comment": "Đặng Thị Ngọc Duyên",
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "created_at": "2026-06-20T12:24:35.923989"
    },
    {
      "time": "2 weeks ago",
      "id": 90,
      "author": "My Dung",
      "replies": [],
      "comment": "My Dung",
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "created_at": "2026-06-20T12:24:35.923989"
    },
    {
      "time": "2 weeks ago",
      "id": 91,
      "author": "Huy Hiền",
      "replies": [],
      "comment": "Huy Hiền",
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "created_at": "2026-06-20T12:24:35.923989"
    },
    {
      "time": "Không rõ",
      "id": 92,
      "author": "Ẩn danh",
      "replies": [],
      "comment": "THƯỞNG THỨC DIFF 2026 TRỌN VẸN – NẠP NĂNG LƯỢNG TẠI MỘC QUÁN, KHÔNG LO CẤM ĐƯỜNGĐêm khai mạc Lễ hội Pháo hoa Quốc tế Đà Nẵng (DIFF 2026) chính thức bùng nổ vào hôm nay (30/05)! Để chuyến đi chơi, xem pháo hoa của bạn và gia đình không bị gián đoạn bởi các tuyến đường phân luồng, Mộc Quán đã cập nhật nhanh lộ trình \"vàng\
      "created_at": "2026-06-20T12:24:35.923990"
    },
    {
      "time": "2 weeks ago",
      "id": 94,
      "author": "Loan Còi",
      "replies": [
        "Hải sản Mộc quán Đà Nẵng replied · 1 reply"
      ],
      "comment": "mình muốn đặt bàn trưa thứ 7",
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "created_at": "2026-06-20T12:24:35.923991"
    },
    {
      "time": "2 weeks ago",
      "id": 95,
      "author": "Trần Lê Khánh Ly",
      "replies": [
        "Hải sản Mộc quán Đà Nẵng replied · 1 reply"
      ],
      "comment": "hi em muốn đặt bàn ạ",
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "created_at": "2026-06-20T12:24:35.923991"
    },
    {
      "time": "Không rõ",
      "id": 96,
      "author": "Ẩn danh",
      "replies": [],
      "comment": "ĐÁNH THỨC MỌI GIÁC QUAN: THU TRỌN BIỂN CẢ VỚI ĐẠI TIỆC SASHIMI TẠI MỘC QUÁNNếu là một tín đồ say mê phong vị nguyên bản của biển khơi, bạn tuyệt đối không thể bỏ qua \"thế giới\" Sashimi tuyệt hảo tại Mộc Quán! Chúng mình mang đến một trải nghiệm ẩm thực tinh tế, nơi độ tươi ngon thuần khiết nhất được tôn vinh qua từng lát cắt:Hàu Sữa Mọng Nước: Trải nghiệm vị béo ngậy tan ngay nơi đầu lưỡi, mang theo chút mặn mòi nồng nàn đầy quyến rũ.Tôm Sú Tươi Sống: Từng thớ thịt săn chắc, ngọt lịm và giòn sật khiến thực khách phải xiêu lòng ngay từ lần thử đầu tiên.Cá Mú Trắng Ngần: Tinh khôi, thanh mát với độ dai giòn sần sật đặc trưng – một sự thăng hoa vị giác đích thực.Tôm Hùm Đẳng Cấp: Trải nghiệm sự xa xỉ với vị ngọt thanh tao và độ chắc khỏe của \"vua hải sản\", đủ sức chinh phục cả những vị khách khó tính nhất.Tại Mộc Quán Đà Nẵng – mỗi lát cắt, mỗi món là một \"cảm xúc\" khác biệt! Nguồn hải sản được bắt sống trực tiếp tại hồ, chế biến điệu nghệ ngay khi khách gọi để giữ trọn vẹn sự tinh khiết và hương vị thanh tao nguyên bản.Đừng chần chừ thêm nữa, hãy để Mộc Quán chiêu đãi bạn một bữa tiệc thị giác và vị giác ngay hôm nay! Inbox hoặc gọi ngay hotline để giữ cho mình vị trí bàn đẹp nhất nhé!—-----------------AWAKEN ALL SENSES: CAPTURE THE OCEAN WITH A SASHIMI FEAST AT MOC QUANIf you are a devotee of the ocean's original flavors, you absolutely cannot miss the exquisite \"world\" of Sashimi at Moc Quan! We bring you a refined culinary experience, where the purest freshness is honored in every slice:Plump Fresh Oysters: Experience the rich, creamy texture that melts on the tip of your tongue, carrying a captivating and robust briny taste.Fresh Black Tiger Shrimp: Every firm, sweet, and crunchy bite will win diners' hearts from the very first taste.Pristine White Grouper: Pure and refreshing with its signature crunchiness – a true elevation of the taste buds.Premium Lobster: Experience luxury with the elegant sweetness and firm texture of the \"king of seafood,\" enough to conquer even the most demanding guests.At Moc Quan Da Nang – every slice, every dish is a different \"emotion\"! Our seafood is caught live directly from the tanks and artfully prepared the moment you order, preserving its pure essence and original elegant flavor.Do not hesitate any longer, let Moc Quan treat you to a visual and gustatory feast today! Inbox or call our hotline now to secure the best table!—-----------------------------------------------𝐌𝐨̣̂𝐜 𝐒𝐞𝐚𝐟𝐨𝐨𝐝 𝐑𝐞𝐬𝐭𝐚𝐮𝐫𝐚𝐧𝐭CS1 (Đà Nẵng): 26 Tô Hiến Thành, Sơn Trà, Đà NẵngHotline: 0905 665 058 - 0964 531 153CS2 (Nha Trang): 74 - 76 Hồng Bàng, Tân Lập, Nha TrangHotline: 0934 981 180Giờ phục vụ: 10:30 AM – 23:45 PM (22:30 bếp đóng)#MocQuan#MocSeafood#HaiSanTuoiSong#ReviewAnUong#DaNang",
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "created_at": "2026-06-20T12:24:35.923991"
    },
    {
      "time": "3 weeks ago",
      "id": 97,
      "author": "Minh Anh",
      "replies": [
        "Hải sản Mộc quán Đà Nẵng replied · 1 reply"
      ],
      "comment": "check whatsapp giúp em nha ạ",
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "created_at": "2026-06-20T12:24:35.923992"
    },
    {
      "time": "Không rõ",
      "id": 98,
      "author": "Ẩn danh",
      "replies": [
        "Hải sản Mộc quán Đà Nẵng replied · 1 reply"
      ],
      "comment": "em xin menu ạ",
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "created_at": "2026-06-20T12:24:35.923992"
    },
    {
      "time": "2 weeks ago",
      "id": 99,
      "author": "Nga Tran",
      "replies": [],
      "comment": "Alo",
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "created_at": "2026-06-20T12:24:35.923993"
    },
    {
      "time": "Không rõ",
      "id": 100,
      "author": "Ẩn danh",
      "replies": [],
      "comment": "THƯỞNG THỨC TINH HOA ĐẠI DƯƠNG TẠI MỘC QUÁN: CHẮC THỊT, ĐẬM VỊ, HAO MỒI!Bỏ qua mọi lời khen hoa mỹ đi, đây là danh sách những siêu phẩm \"ăn là dính\" đã làm nên tên tuổi của Mộc. Đi ăn nhóm, cứ gọi ngay menu này đảm bảo ai cũng gật gù:Tôm Hùm Nướng Phô Mai: Thịt tôm dai ngọt ngập trong lớp phô mai nướng xém vàng, kéo sợi mỏi tay. Béo, thơm mà không hề ngấy!Cua Sốt Sing: Best-seller càn quét mọi bàn tiệc! Thịt cua chắc nịch quyện cùng sốt sánh mịn, cay the đậm đà. Nhớ gọi thêm bánh mì nướng để vét cho bằng sạch phần sốt \"thần thánh\" này nha.Cá Chìa Vôi Nướng: \"Mồi bén\" số 1! Da nướng trên than giòn rụm, thịt cá trắng phau ngọt lịm. Cuốn xíu rau rừng, chấm ngập mắm nêm là nhức nách.Tôm Sú Sốt Bơ Tỏi: Chân ái cho team thích đậm vị. Tôm bự, dai giòn sần sật, đẫm sốt bơ tỏi thơm nức mũi, ăn xong mút tay chùn chụt vẫn thấy thèm.Lẩu Mộc: Chốt hạ êm ru với nồi lẩu ngập tràn topping hải sản bơi sống. Nước lẩu ngọt thanh bưng ra sôi sùng sục, húp một ngụm là ấm cả bụng.Chỉ cần nhìn mâm đồ ăn là đủ hiểu độ uy tín rồi ha? Tối nay thèm hải sản, tag ngay hội cạ cứng ghé Mộc liền nhé!—----------------------------------------------------------------------ENJOY THE OCEAN'S ESSENCE AT MOC QUAN: FIRM MEAT, RICH FLAVOR, PERFECT FOR DRINKING COMPANION!Forget the fancy words, here is the ultimate \"must-try\" list that built Moc Quan's reputation. Order these for your group, and everyone will leave satisfied:Grilled Lobster with Cheese: Sweet, firm lobster meat buried under a golden, stretchy layer of baked cheese. Rich, creamy, and absolutely addictive!Singapore Chilli Crab: The ultimate table-pleaser! Meaty crab coated in a rich, spicy, and savory sauce. Don't forget to order extra toasted bread to wipe the plate clean!Grilled Pipefish: The perfect dish to share. Crispy grilled skin, pure white and naturally sweet meat, wrapped in rice paper and dipped in our signature sauce.Tiger Prawns in Garlic Butter: Big, crunchy prawns slathered in an aromatic, finger-licking garlic butter sauce.Moc Hotpot: The perfect finale. A refreshing, naturally sweet loaded with premium live seafood to warm up your stomach.The real pictures below say it all! Tag your foodie squad and head to Moc Quan tonight for a feast!—-----------------------------------------------𝐌𝐨̣̂𝐜 𝐒𝐞𝐚𝐟𝐨𝐨𝐝 𝐑𝐞𝐬𝐭𝐚𝐮𝐫𝐚𝐧𝐭CS1 (Đà Nẵng): 26 Tô Hiến Thành, Sơn Trà, Đà NẵngHotline: 0905 665 058 - 0964 531 153CS2 (Nha Trang): 74 - 76 Hồng Bàng, Tân Lập, Nha TrangHotline: 0934 981 180Giờ phục vụ: 10:30 AM – 23:45 PM (22:30 bếp đóng)#MocQuan#MocSeafood#HaiSanTuoiSong#ReviewAnUong#DaNang",
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "created_at": "2026-06-20T12:24:35.923993"
    },
    {
      "time": "2 weeks ago",
      "id": 101,
      "author": "Nguyễn Ly",
      "replies": [
        "Hải sản Mộc quán Đà Nẵng replied · 1 reply"
      ],
      "comment": "e xin menu",
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "created_at": "2026-06-20T12:24:35.923994"
    },
    {
      "time": "4 days ago",
      "id": 102,
      "author": "Dung Thai Ngoc",
      "replies": [
        "Hải sản Mộc quán Đà Nẵng replied · 1 reply"
      ],
      "comment": "Mình xin menu nhé",
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "created_at": "2026-06-20T12:24:35.923994"
    },
    {
      "time": "3 weeks ago",
      "id": 103,
      "author": "Loan Moon",
      "replies": [
        "Hải sản Mộc quán Đà Nẵng replied · 1 reply"
      ],
      "comment": "mình xin menu ak",
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "created_at": "2026-06-20T12:24:35.923994"
    },
    {
      "time": "Không rõ",
      "id": 104,
      "author": "Ẩn danh",
      "replies": [],
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "created_at": "2026-06-20T12:24:35.923995"
    },
    {
      "time": "Không rõ",
      "id": 105,
      "author": "Ẩn danh",
      "replies": [],
      "comment": "Bạn là \"fan cứng\" của Mộc Quán tại Đà Nẵng và sắp có chuyến vi vu Nha Trang? Đừng lo, \"người anh em\" của Mộc luôn có mặt tại phố biển để đồng hành cùng bạn đó nha!Mộc Quán tự hào mang trọn phong vị và tinh thần vốn có đến với Nha Trang. Không chỉ kế thừa sự chỉn chu từ cơ sở Đà Nẵng, Mộc Nha Trang còn sở hữu không gian rộng \"bất tận\", cực kỳ thoáng đãng, sẵn sàng cho những buổi tụ tập, ăn uống thả ga mà không lo chật chội.Video dưới đây chính là \"tấm vé\" đưa bạn ghé thăm không gian tại Nha Trang. Hãy để Mộc tiếp tục là điểm dừng chân lý tưởng sau một ngày dài khám phá phố biển, nơi bạn trút bỏ âu lo và tận hưởng những bữa tiệc hải sản tươi rói cùng bạn bè.Dù ở Đà Nẵng hay Nha Trang, Mộc vẫn luôn sẵn sàng chào đón bạn! Lưu lại ngay địa chỉ để mỗi chuyến đi là một trải nghiệm ẩm thực trọn vẹn nhất nhé!---------------------------------------------------------------Planning a trip to Nha Trang but already missing the vibe of Moc Quán in Da Nang? Don’t worry, we’ve got you covered!Moc Quán is proud to bring our signature flavors and hospitality to the coastal city of Nha Trang. Inheriting the excellence from our Da Nang branch, our Nha Trang location boasts a spacious and breezy atmosphere—perfect for gatherings, celebrations, or simply enjoying a feast without feeling crowded.Check out the video below for a glimpse of our Nha Trang space. Whether you’re in Da Nang or Nha Trang, let Moc Quán be your go-to spot to unwind and indulge in the freshest seafood with your friends.Save our addresses below and join us for an unforgettable dining experience!———————————𝐌𝐨𝐜 𝐒𝐞𝐚𝐟𝐨𝐨𝐝 𝐑𝐞𝐬𝐭𝐚𝐮𝐫𝐚𝐧𝐭CS1 (Da Nang): 26 To Hien Thanh, Son Tra, Da NangHotline: 0905 665 058 - 0964 531 153CS2 (Nha Trang): 74 - 76 Hong Bang, Tan Lap, Nha TrangHotline: 0934 981 180Opening hours: 10:30 AM – 23:45 PM (Kitchen closes at 22:30)#MocSeafood#HaiSanTuoiSong#DaNangFood#NhaTrangFood",
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "created_at": "2026-06-20T12:24:35.923995"
    },
    {
      "time": "3 weeks ago",
      "id": 106,
      "author": "Quỳnh Trang Lê",
      "replies": [
        "Hải sản Mộc quán Đà Nẵng replied · 1 reply"
      ],
      "comment": "An rat nhieu lan roi . Ngon  ngan vien nhiet Tinh",
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0",
      "created_at": "2026-06-20T12:24:35.923996"
    }
  ],
  "events": [
    {
      "node_name": "suggest",
      "seq": 1,
      "created_at": "2026-06-20T12:24:35.918603",
      "payload": {
        "status": "started",
        "query": "nhà hàng quán nhậu hải sản Đà Nẵng"
      },
      "id": 7,
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0"
    },
    {
      "node_name": "suggest",
      "seq": 2,
      "created_at": "2026-06-20T12:24:35.918605",
      "payload": {
        "status": "done",
        "total": 41
      },
      "id": 8,
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0"
    },
    {
      "node_name": "serp",
      "seq": 3,
      "created_at": "2026-06-20T12:24:35.918606",
      "payload": {
        "status": "started",
        "query": "nhà hàng quán nhậu hải sản Đà Nẵng"
      },
      "id": 9,
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0"
    },
    {
      "node_name": "serp",
      "seq": 4,
      "created_at": "2026-06-20T12:24:35.918607",
      "payload": {
        "status": "done",
        "top_urls": 9
      },
      "id": 10,
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0"
    },
    {
      "node_name": "facebook",
      "seq": 5,
      "created_at": "2026-06-20T12:24:35.918608",
      "payload": {
        "status": "started",
        "fb_url": "https://www.facebook.com/mocseafood/"
      },
      "id": 11,
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0"
    },
    {
      "node_name": "facebook",
      "seq": 6,
      "created_at": "2026-06-20T12:24:35.918609",
      "payload": {
        "status": "done",
        "posts": 11,
        "comments": 36
      },
      "id": 12,
      "business_id": "f189dcab-f003-49e3-8cee-741bf88a06e0"
    }
  ]
}

# %%
# CELL 1: IMPORTS═══════════════════════════════


import json, asyncio, re
from typing import Dict, Any, List
from datetime import datetime, timezone
from app.llm_clients import call_groq

# %%
# CELL 2A: SLICER — Hàm phụ══════════════════════════════════

def _k1_posts(posts): 
    return sorted(posts, key=lambda p: len(p.get("content","")), reverse=True)[:5]

def _k2_posts(posts):
    def cls(p):
        c = p.get("content","").lower()
        if "michelin" in c: return 0
        if any(x in c for x in ["diff","pháo hoa","sự kiện"]): return 1
        if any(x in c for x in ["giao hàng","tận nhà","delivery","take-away"]): return 2
        return 3
    b = [[],[],[],[]]
    for p in posts: b[cls(p)].append(p)
    r = []
    for bucket in b: r.extend(bucket[:2])
    if len(r) < 8:
        used = {p["id"] for p in r}
        for p in posts:
            if p["id"] not in used: r.append(p)
            if len(r) >= 8: break
    return r[:8]

def _k3_posts(posts):
    minimal = []
    for p in posts:
        c = p.get("content","")
        s = [x.strip() for x in c.replace("!",".").replace("?",".").split(".") if x.strip()]
        minimal.append({
            "id": p["id"], "first": s[0][:100] if s else "",
            "last": s[-1][:100] if len(s)>1 else "", "wc": len(c.split()),
            "emoji": any(ord(ch)>10000 for ch in c),
            "hash": "#" in c, "bi": "----------" in c, "bull": c.count("\n-")
        })
    return minimal, posts[:2]

def _k4_posts(posts):
    m = ["Hotline:","CS1","Đặt bàn","Inbox","Gọi điện"]
    r = [p for p in posts if any(x in p.get("content","") for x in m)]
    return r if len(r)>=3 else posts[-4:]

# %%
# CELL 2B: SLICER — prepare_kien_inputs

def prepare_kien_inputs(data):
    posts = data.get("posts",[])
    comments = data.get("comments",[])
    serp = data.get("result",{}).get("serp_data",{})
    fb = data.get("result",{}).get("fb_brand",{})
    mc = [c for c in comments if len(c.get("comment",""))>20 and c.get("author")!="Ẩn danh"]
    m3, f3 = _k3_posts(posts)
    return {
        "k1": {"posts": _k1_posts(posts), "fb": fb.get("intro","")[:2000],
               "name": data.get("task",{}).get("business_name","")},
        "k2": {"posts": _k2_posts(posts), "comments": mc[:15],
               "name": data.get("task",{}).get("business_name","")},
        "k3": {"minimal": m3, "full": f3,
               "kc": serp.get("keyword_cluster",[]), "cp": serp.get("competitor_pattern",[])},
        "k4": {"posts": _k4_posts(posts),
               "bc": [c for c in mc if any(x in c.get("comment","").lower() 
                      for x in ["đặt bàn","menu","hotline","giá"])][:10]}
    }

# %%
# CELL 3A: PROMPT BUILDERS — K1 & K2

def _pk1(i):
    pt = "\n\n---\n".join([f"ID:{p['id']}\n{p.get('content','')[:3000]}" for p in i["posts"]])
    return f"""Bạn là chuyên gia brand DNA. Đọc bài viết và viết PHÂN TÍCH TỰ NHIÊN về LINH HỒN thương hiệu {i["name"]}.

FB INTRO: {i["fb"][:1500]}

BÀI VIẾT:
{pt}

Viết 1 đoạn văn liền mạch 200-400 từ: brand tự hào điều gì NHẤT? Không bao giờ làm gì vì tiền? 3 metaphor tự mô tả? Khác biệt đối thủ?

KHÔNG dùng "thân thiện", "chuyên nghiệp", "chất lượng".

QUAN TRỌNG — KẾT THÚC bằng EXACTLY 5 dòng, mỗi dòng 1 SIGNATURE PHRASE trong ngoặc kép:
"phrase 1"
"phrase 2"
"phrase 3"
"phrase 4"
"phrase 5"

Các phrase này PHẢI là những câu brand DÙNG NHIỀU LẦN trong bài viết trên."""

def _pk2(i):
    pt = "\n\n---\n".join([f"[{p['id']}]\n{p.get('content','')[:2500]}" for p in i["posts"]])
    ct = "\n".join([f"- {c['author']}: {c.get('comment','')[:200]}" for c in i["comments"]])
    return f"""Bạn là linguist phân tích tone & style của {i["name"]}. Đọc bài viết và comments, viết PHÂN TÍCH TỰ NHIÊN.

BÀI VIẾT:
{pt}

COMMENTS:
{ct}

Viết 1 đoạn 200-400 từ: emotional arc? Tone chính (CHỌN 2-3 TỪ CỤ THỂ)? Pronoun pattern? Bilingual strategy? 4 sliders (0-100): funny-serious, formal-casual, respectful-irreverent, enthusiastic-matter_of_fact.

KHÔNG JSON. Viết như báo cáo phân tích."""

def _pk2(i):
    pt = "\n\n---\n".join([f"[{p['id']}]\n{p.get('content','')[:2500]}" for p in i["posts"]])
    ct = "\n".join([f"- {c['author']}: {c.get('comment','')[:200]}" for c in i["comments"]])
    return f"""Bạn là linguist phân tích tone & style của {i["name"]}. Đọc bài viết và comments, viết PHÂN TÍCH TỰ NHIÊN.

BÀI VIẾT:
{pt}

COMMENTS:
{ct}

Viết 1 đoạn 200-400 từ: emotional arc? Tone chính (CHỌN 2-3 TỪ CỤ THỂ)? Pronoun pattern? Bilingual strategy? 4 sliders (0-100): funny-serious, formal-casual, respectful-irreverent, enthusiastic-matter_of_fact.

KHÔNG JSON. Viết như báo cáo phân tích."""

# %%
# CELL 3B: PROMPT BUILDERS — K3 & K4

def _pk3(i):
    mt = "\n".join([f"P{m['id']}: first='{m['first']}' last='{m['last']}' wc={m['wc']} emo={m['emoji']} hash={m['hash']} bi={m['bi']} bull={m['bull']}" for m in i["minimal"]])
    ft = "\n\n---\n".join([p.get("content","")[:2000] for p in i["full"]])
    return f"""Bạn là data analyst. Đọc metadata và trả lời BẰNG SỐ LIỆU.

META 11 POSTS:
{mt}

FULL SAMPLES:
{ft}

KEYWORDS: {i['kc']}

YÊU CẦU — Trả lời CHÍNH XÁC bằng số liệu từ metadata:
1. Bao nhiêu post có emoji? (đếm từ cột emo=true)
2. Bao nhiêu post có hashtag? (đếm từ cột hash=true)
3. Hashtag ở đầu hay cuối post?
4. Bao nhiêu post có bullet points? (đếm từ cột bull>0)
5. Bullet style là gì? (dựa vào first/last line)
6. Top 10 phrases brand DÙNG NHIỀU NHẤT (từ full samples, đếm lặp lại)
7. Top 5 words KHÔNG BAO GIỜ dùng (so với keywords ngành)
8. 5 SIGNATURE PHRASES — đặt trong ngoặc kép, mỗi phrase 1 dòng

KHÔNG phân tích. KHÔNG suy đoán. Chỉ trả lời 8 câu trên."""
    

def _pk4(i):
    pt = "\n\n---\n".join([f"[{p['id']}]\n{p.get('content','')[-1500:]}" for p in i["posts"]])
    bt = "\n".join([f"- {c['author']}: {c.get('comment','')[:150]}" for c in i["bc"]])
    return f"""Bạn là conversion strategist phân tích CTA.

CTA SECTIONS:
{pt}

BOOKING COMMENTS:
{bt}

Viết 1 đoạn 150-300 từ: CTA style direct/soft? Top 5 phrases? Urgency framing? Conversion triggers? CTA components? Response pattern?

KHÔNG JSON. Audit report."""

# %%
# CELL 4: RUN 4 KIENS SONG SONG

async def _k1(i): return call_groq(_pk1(i), 1500)
async def _k2(i): return call_groq(_pk2(i), 1500)
async def _k3(i): return call_groq(_pk3(i), 1500)
async def _k4(i): return call_groq(_pk4(i), 1200)

async def run_kiens(data):
    inp = prepare_kien_inputs(data)
    print(f"K1:{len(inp['k1']['posts'])} K2:{len(inp['k2']['posts'])}+{len(inp['k2']['comments'])} K3:{len(inp['k3']['minimal'])}+{len(inp['k3']['full'])} K4:{len(inp['k4']['posts'])}+{len(inp['k4']['bc'])}")
    r = await asyncio.gather(
        asyncio.create_task(_k1(inp["k1"])),
        asyncio.create_task(_k2(inp["k2"])),
        asyncio.create_task(_k3(inp["k3"])),
        asyncio.create_task(_k4(inp["k4"]))
    )
    return {"k1": r[0], "k2": r[1], "k3": r[2], "k4": r[3]}

# %%
# CELL 5A: AGGREGATOR HELPERS — String utils

def _between(t, s, e=None):
    try:
        i = t.lower().find(s.lower())
        if i==-1: return ""
        i += len(s)
        if e:
            j = t.lower().find(e.lower(), i)
            return t[i:j].strip() if j!=-1 else t[i:].strip()
        return t[i:].strip()
    except: return ""

def _phrases(t, prefix):
    r, found = [], False
    for line in t.split("\n"):
        if prefix.lower() in line.lower(): found=True; continue
        if found and line.strip().startswith(("- ","• ","* ","1. ","2. ")):
            c = line.strip("- •*123456789. ").strip()
            if c and len(c)>3: r.append(c)
        elif found and line.strip()=="": continue
        elif found and not line.strip().startswith(("-","•","*")): break
    return r[:10]

def _slider(t, lo, hi):
    t = t.lower()
    lc, hc = t.count(lo), t.count(hi)
    tot = lc+hc
    return 50 if tot==0 else int((hc/tot)*100)

# %%
# CELL 5B: AGGREGATOR HELPERS — Extractors

def _pronouns(t):
    t = t.lower()
    r = {"ai": "Chúng tôi", "reader": "Bạn"}
    if t.count("nhà mộc") > 2: r["brand_ref"] = "nhà Mộc"
    elif t.count("mộc quán") > 2: r["brand_ref"] = "Mộc Quán"
    return r

def _tone_base(t):
    t = t.lower()
    sp = ["proud","humble","warm","precise","grateful","excited","passionate","earnest","dignified"]
    found = [w for w in sp if w in t]
    if found: return [w.title() for w in found[:3]]
    r = []
    if any(x in t for x in ["michelin","vinh danh","tự hào","vinh dự","ngôi sao","bệ phóng","đích đến"]):
        r.append("Proud")
    if any(x in t for x in ["humble","khiêm tốn","tri ân","cảm ơn","gật đầu"]):
        r.append("Humble")
    if any(x in t for x in ["warm","ấm cúng","chào đón","nhà mộc"]):
        r.append("Warm")
    if any(x in t for x in ["grateful","tri ân","cảm ơn sâu sắc","đồng hành"]):
        r.append("Grateful")
    if any(x in t for x in ["precise","chính xác","chi tiết","tuyệt đối"]):
        r.append("Precise")
    if any(x in t for x in ["excited","hào hứng","bùng nổ","rộn ràng"]):
        r.append("Excited")
    return r if r else ["Earnest","Warm"]

def _sig_phrases(k1, k3):
    k1_lines = [l.strip() for l in k1.strip().split("\n") if l.strip().startswith('"') and l.strip().endswith('"')]
    q = [l.strip('"') for l in k1_lines if len(l.strip('"')) > 10]
    q += re.findall(r'"([^"]{10,80})"', k3)
    sig_sec = _between(k3, "signature", "format") or _between(k3, "8.", "\n\n") or k3[-800:]
    q += re.findall(r'"([^"]{10,80})"', sig_sec)
    seen, uniq = set(), []
    for p in q:
        cl = p.strip().lower()
        if cl not in seen and len(p) > 15:
            seen.add(cl); uniq.append(p.strip())
    return uniq[:5]

def _format_rules(k3):
    t = k3.lower()
    emo_match = re.search(r'(\d+)\s*post.*emoji', t)
    emo_count = int(emo_match.group(1)) if emo_match else t.count("emoji")
    hash_match = re.search(r'(\d+)\s*post.*hash', t)
    hash_count = int(hash_match.group(1)) if hash_match else t.count("hash")
    bull_match = re.search(r'(\d+)\s*post.*bull', t)
    bull_count = int(bull_match.group(1)) if bull_match else t.count("bull")
    return {
        "paragraphMaxSentences": 5,
        "useEmoji": emo_count > 0,
        "useHashtags": hash_count > 0,
        "bulletPointStyle": "dash" if bull_count > 0 or "dash" in t or "-" in t else "none"
    }
    
def _avoid(k3):
    s = _between(k3, "không bao giờ", "signature") or _between(k3, "avoid", "signature")
    w = []
    for l in (s or "").split("\n"):
        c = l.strip("- •*123456789. \"'").strip()
        if c and len(c) < 30 and len(c) > 2 and not

def _cta_phrases(k4):
    r = []
    for line in k4.split("\n"):
        line = line.strip()
        if any(m in line.lower() for m in ["đặt bàn","hotline","inbox","gọi điện"]):
            c = line.strip("- •*123456789. ").strip()
            if c and len(c)<60: r.append(c)
    return r[:5] if r else ["Đặt bàn ngay","Gọi Hotline để giữ chỗ","Inbox Fanpage"]
# Out:
#   Cell In[13], line 63
#     if c and len(c) < 30 and len(c) > 2 and not
#                                                ^
# SyntaxError: invalid syntax

# %%
# CELL 6: AGGREGATOR — Ép schema

def aggregate(k1, k2, k3, k4, bid, bname):
    now = datetime.now(timezone.utc).isoformat()
    sig = _sig_phrases(k1, k3)
    personality = " ".join([p.strip() for p in k1.strip().split("\n\n") if len(p.strip())>50][:2])[:800]
    return {
        "id": "05ecf6ad-eb61-45e0-b3f8-6bf2bc916914",
        "business_id": bid, "name": bname,
        "purpose": "Chuyên phục vụ hải sản tươi sống, mang đến trải nghiệm ẩm thực đẳng cấp",
        "channels": ["social","blog","email"],
        "desired_tone": " ".join(_tone_base(k2)),
        "target_audience": "Thực khách yêu thích hải sản tươi sống, tìm kiếm trải nghiệm ẩm thực chất lượng cao",
        "personality": personality,
        "tone": {"base": _tone_base(k2), "overrides": {"blog_web": _tone_base(k2)}},
        "style": {"sentenceLength":"medium","voice":"active","perspective":"first","pronouns":_pronouns(k2)},
        "vocabulary": {
            "wordsToUse": sig[:3] if sig else ["hải sản tươi sống"],
            "wordsToAvoid": _avoid(k3),
            "phrasesToUse": sig[:5], "phrasesToAvoid": ["giá rẻ","buffet"], "topicsToAvoid": []
        },
        "format_rules": _format_rules(k3),
        "cta_style": {
            "style": "direct" if any(x in k4.lower() for x in ["direct","mạnh mẽ","ngay"]) else "mixed",
            "phrases": _cta_phrases(k4)
        },
        "examples": [{
            "input": f"Tìm kiếm nhà hàng hải sản tại {bname}",
            "output": f"{bname.title()} chào đón bạn! {sig[0] if sig else ''} Liên hệ ngay để trải nghiệm hải sản tươi sống.",
            "contentType": "blog_web"
        }],
        "website_url": "https://www.facebook.com/mocseafood/",
        "uploaded_files": [],
        "tone_funny_serious": _slider(k2,"funny","serious"),
        "tone_formal_casual": _slider(k2,"formal","casual"),
        "tone_respectful_irreverent": _slider(k2,"irreverent","respectful"),
        "tone_enthusiastic_matter_of_fact": _slider(k2,"matter of fact","enthusiastic"),
        "is_default": "0", "created_at": now, "updated_at": now
    }

# %%
# CELL 7: MAIN — Chạy từ data → brand_voice_state

async def extract_brand_voice(data):
    print("🔬 Slicing...")
    ko = await run_kiens(data)
    print("✅ 4 kiến xong. Aggregating...")
    st = aggregate(ko["k1"], ko["k2"], ko["k3"], ko["k4"],
                   data.get("task",{}).get("business_id",""),
                   data.get("task",{}).get("business_name",""))
    print(f"Tone: {st['tone']['base']} | Sliders: f={st['tone_funny_serious']} fo={st['tone_formal_casual']} r={st['tone_respectful_irreverent']} e={st['tone_enthusiastic_matter_of_fact']}")
    return st

# CHẠY (cell 1 đã có data = {...}):
# brand_voice_state = asyncio.run(extract_brand_voice(data))
# print(json.dumps(brand_voice_state, ensure_ascii=False, indent=2))

# %%
brand_voice_state = asyncio.run(extract_brand_voice(data))
print(json.dumps(brand_voice_state, ensure_ascii=False, indent=2))
