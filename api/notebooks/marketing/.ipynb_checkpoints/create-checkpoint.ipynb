# %%
import nest_asyncio
nest_asyncio.apply()  # Cho phép nest event loop trong Jupyter

import sys
sys.path.insert(0, "/home/duoc/workflow/api")  # thư mục chứa folder app/
print("Cấu hình sys.path thành công! Thư mục hiện tại:")
# Out:
# Cấu hình sys.path thành công! Thư mục hiện tại:

# %%
from app.marketing.workflow import marketing_graph


# Visualize
try:
    img_bytes = marketing_graph.get_graph(xray=True).draw_mermaid_png()
    from IPython.display import Image, display
    display(Image(data=img_bytes))
except Exception as e:
    print(f"⚠️ Viz error: {e}")
    print(marketing_graph.get_graph(xray=True).draw_mermaid())
    
# ═══════════════════════════════════════════════════════
# KHỞI CHẠY HỆ THỐNG
# ═══════════════════════════════════════════════════════

result = await marketing_graph.ainvoke(
    {
        "session_id": "4f21fd60",
        "request": "Viết bài viết giới thiệu về dịch vụ buffet sáng của khách sạn biển nongnghiepho2",
        "brand_id": "ccc31d28-c904-40e5-9f56-0117c63f1d1d",
        "template": "blog",      
        "context": {},
        "draft": None,
        "approved": False,
        "publish_status": "pending",
        "usage": {},
        "error": None,
        "visual_intent": {},
        "memory_history": []
    },
    config={"configurable": {"thread_id": "content_generation_thread"}}
)

print(result.get("draft", "No draft generated"))
# Out:
# 2026-06-15 21:57:11,206 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-06-15 21:57:11,214 INFO sqlalchemy.engine.Engine SELECT brands.id, brands.name, brands.owner_id, brands.business_id, brands.created_at, brands.updated_at, brands.deleted_at, brand_profiles_1.brand_id, brand_profiles_1.positioning, brand_profiles_1.audience, brand_profiles_1.visual_identity, brand_profiles_1.version, brand_profiles_1.updated_at AS updated_at_1, brand_profiles_1.mined_at, brand_voice_rules_1.id AS id_1, brand_voice_rules_1.brand_id AS brand_id_1, brand_voice_rules_1.rule_type, brand_voice_rules_1.value, brand_messaging_1.id AS id_2, brand_messaging_1.brand_id AS brand_id_2, brand_messaging_1.message_type, brand_messaging_1.value AS value_1, brand_messaging_1.parent_id, brand_messaging_1.objection, brand_messaging_1.counter
# ...

# %%
from google import genai
import os
from app.config import get_settings
_s = get_settings()
# Thay 'YOUR_API_KEY_HERE' bằng key thật của bạn
# Hoặc dùng luôn biến môi trường nếu bạn đã set
# Khởi tạo client tạm trong Notebook
temp_client = genai.Client(api_key=_s.GEMINI_API_KEY)

# Chạy lệnh liệt kê model
try:
    models = temp_client.models.list()
    for m in models:
        print(f"Model name: {m.name}")
except Exception as e:
    print(f"Lỗi: {e}")
# Out:
# Model name: models/gemini-2.5-flash
# Model name: models/gemini-2.5-pro
# Model name: models/gemini-2.0-flash
# Model name: models/gemini-2.0-flash-001
# Model name: models/gemini-2.0-flash-lite-001
# Model name: models/gemini-2.0-flash-lite
# Model name: models/gemini-2.5-flash-preview-tts
# Model name: models/gemini-2.5-pro-preview-tts
# Model name: models/gemma-4-26b-a4b-it
# Model name: models/gemma-4-31b-it
# Model name: models/gemini-flash-latest
# Model name: models/gemini-flash-lite-latest
# Model name: models/gemini-pro-latest
# Model name: models/gemini-2.5-flash-lite
# Model name: models/gemini-2.5-flash-image
# Model name: models/gemini-3-pro-preview
# Model name: models/gemini-3-flash-preview
# Model name: models/gemini-3.1-pro-preview
# Model name: models/gemini-3.1-pro-preview-customtools
# Model name: models/gemini-3.1-flash-lite-preview
# Model name: models/gemini-3.1-flash-lite
# Model name: models/gemini-3-pro-image-preview
# Model name: models/gemini-3-pro-image
# ...

# %%
from app.config import get_settings
_s = get_settings()
print("MODEL =", repr(_s.GEMINI_MODEL))
print("KEY =", _s.GEMINI_API_KEY[:12])
# Out:
# MODEL = 'gemini-2.5-flash-lite'
# KEY = AIzaSyBrx7ay

# %%
from app.config import get_settings
from google import genai

_s = get_settings()

client = genai.Client(
    api_key=_s.GEMINI_API_KEY
)

response = client.models.generate_content(
    model="gemini-2.5-flash-lite",
    contents="hello"
)

print(response.text)
# Out:
# Hello! How can I help you today?
