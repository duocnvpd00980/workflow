# %%
import nest_asyncio
nest_asyncio.apply()  # Cho phép nest event loop trong Jupyter

import sys
sys.path.insert(0, "/home/duoc/workflow/api")  # thư mục chứa folder app/
print("Cấu hình sys.path thành công! Thư mục hiện tại:")
# Out:
# Cấu hình sys.path thành công! Thư mục hiện tại:

# %%
from __future__ import annotations
from typing import Annotated, Any, Optional, TypedDict
import operator
import uuid
from langgraph.graph import StateGraph, START, END
from langgraph.checkpoint.memory import MemorySaver
from app.chat.workflow import chat_graph
from app.db import init_db, AsyncSessionLocal
from app.chat.models import Conversation, Message


# ── Seed dữ liệu test (Conversation + Message thật) ────────
async def seed_test_data():
    async with AsyncSessionLocal() as db:
        conv = Conversation(title="Test conversation")
        db.add(conv)
        await db.flush()  # để có conv.id trước khi commit

        msg = Message(
            conversation_id=conv.id,
            role="assistant",
            content="",
            status="pending",
        )
        db.add(msg)
        await db.commit()

        print(f"🆔 conversation_id = {conv.id}")
        print(f"🆔 msg_id          = {msg.id}")
        return conv.id, msg.id


# ── KHỞI CHẠY HỆ THỐNG ────────────────────────────────────
async def run_workflow():
    # Đảm bảo toàn bộ model SQLAlchemy được import/đăng ký
    # trước khi graph chạy các node truy vấn DB (load_brand_voice, load_rag, save_result)
    await init_db()

    # Tạo Conversation + Message thật trong DB để save_result có thể update
    conv_id, msg_id = await seed_test_data()

    # Khai báo Input map chuẩn xác, khít 100% với các trường trong EditorState
    inputs = {
        "session_id": "blog_gen_001",
        "conversation_id": str(conv_id),
        "msg_id": str(msg_id),
        "instruction": "Viết bài viết giới thiệu về dịch vụ buffet sáng của khách sạn biển nongnghiepho2",
        "brand_id": "nongnghiepho2",
        "business_id": "biz_nongnghiep_001",
        "content_draft": "",
        "knowledge_rag": [],
        "error": None,
    }

    # Thực hiện gọi bất đồng bộ
    result = await chat_graph.ainvoke(
        inputs,
        config={"configurable": {"thread_id": "content_generation_thread"}}
    )

    print("\n====== KẾT QUẢ XỬ LÝ ======")
    if result.get("error"):
        print(f"❌ Thất bại: {result.get('error')}")
    else:
        print(f"✅ Saved DB status: {result.get('saved')}")
        print(f"📝 Nội dung hoàn thiện:\n{result.get('rewritten_text')}")


await run_workflow()

# ── Vẽ graph để kiểm tra cấu trúc ──────────────────────────
img_bytes = chat_graph.get_graph(xray=True).draw_mermaid_png()
from IPython.display import Image, display
display(Image(data=img_bytes))
# Out:
# 2026-06-15 13:30:46,510 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-06-15 13:30:46,511 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("conversation")
# 2026-06-15 13:30:46,512 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-06-15 13:30:46,513 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("message")
# 2026-06-15 13:30:46,514 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-06-15 13:30:46,516 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("businesses")
# 2026-06-15 13:30:46,516 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-06-15 13:30:46,517 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("knowledge_document_source")
# 2026-06-15 13:30:46,518 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-06-15 13:30:46,520 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("knowledge_document_page")
# 2026-06-15 13:30:46,520 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-06-15 13:30:46,522 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("knowledge_image_source")
# 2026-06-15 13:30:46,522 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-06-15 13:30:46,524 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("hotel_room")
# 2026-06-15 13:30:46,524 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-06-15 13:30:46,527 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("workflow_sessions")
# 2026-06-15 13:30:46,528 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-06-15 13:30:46,530 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("brands")
# 2026-06-15 13:30:46,531 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-06-15 13:30:46,533 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("brand_profiles")
# 2026-06-15 13:30:46,534 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-06-15 13:30:46,535 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("brand_voice_rules")
# 2026-06-15 13:30:46,536 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-06-15 13:30:46,537 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("brand_messaging")
# 2026-06-15 13:30:46,538 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-06-15 13:30:46,540 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("brand_content_examples")
# 2026-06-15 13:30:46,540 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-06-15 13:30:46,542 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("pipeline_tasks")
# 2026-06-15 13:30:46,542 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-06-15 13:30:46,546 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("pipeline_events")
# 2026-06-15 13:30:46,546 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-06-15 13:30:46,548 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("research_results")
# 2026-06-15 13:30:46,549 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-06-15 13:30:46,550 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("background_tasks")
# 2026-06-15 13:30:46,551 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-06-15 13:30:46,552 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("task_steps")
# 2026-06-15 13:30:46,553 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-06-15 13:30:46,554 INFO sqlalchemy.engine.Engine COMMIT
# 2026-06-15 13:30:46,612 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-06-15 13:30:46,614 INFO sqlalchemy.engine.Engine INSERT INTO conversation (id, title) VALUES (?, ?) RETURNING created_at
# 2026-06-15 13:30:46,615 INFO sqlalchemy.engine.Engine [generated in 0.00067s] ('5423abe1a03445c4951a0d22f8eef115', 'Test conversation')
# 2026-06-15 13:30:46,619 INFO sqlalchemy.engine.Engine INSERT INTO message (id, conversation_id, role, content, status) VALUES (?, ?, ?, ?, ?) RETURNING created_at
# 2026-06-15 13:30:46,619 INFO sqlalchemy.engine.Engine [generated in 0.00078s] ('8affd1dd10a84398b535501724cd3ae0', '5423abe1a03445c4951a0d22f8eef115', 'assistant', '', 'pending')
# 2026-06-15 13:30:46,621 INFO sqlalchemy.engine.Engine COMMIT
# 🆔 conversation_id = 5423abe1-a034-45c4-951a-0d22f8eef115
# 🆔 msg_id          = 8affd1dd-10a8-4398-b535-501724cd3ae0
# 2026-06-15 13:30:46,630 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-06-15 13:30:46,633 INFO sqlalchemy.engine.Engine SELECT brands.id, brands.name, brands.owner_id, brands.business_id, brands.created_at, brands.updated_at, brands.deleted_at
# FROM brands
# WHERE brands.id = ?
# 2026-06-15 13:30:46,634 INFO sqlalchemy.engine.Engine [generated in 0.00080s] ('nongnghiepho2',)
# 2026-06-15 13:30:46,637 INFO sqlalchemy.engine.Engine ROLLBACK
# 2026-06-15 13:30:46,641 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-06-15 13:30:46,644 INFO sqlalchemy.engine.Engine SELECT message.id, message.conversation_id, message.role, message.content, message.status, message.created_at
# FROM message
# WHERE message.conversation_id = ? AND message.status = ? ORDER BY message.created_at DESC
#  LIMIT ? OFFSET ?
# 2026-06-15 13:30:46,644 INFO sqlalchemy.engine.Engine [generated in 0.00078s] ('5423abe1a03445c4951a0d22f8eef115', 'completed', 10, 0)
# 2026-06-15 13:30:46,646 INFO sqlalchemy.engine.Engine ROLLBACK
# 2026-06-15 13:30:46,648 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-06-15 13:30:46,651 INFO sqlalchemy.engine.Engine SELECT knowledge_document_source.id, knowledge_document_source.title, knowledge_document_source.file_path, knowledge_document_source.document_type, knowledge_document_source.business_id, knowledge_document_source.status, knowledge_document_source.chunk_count, knowledge_document_source.error_message, knowledge_document_source.created_at, knowledge_document_source.updated_at, knowledge_document_source.processed_at
# FROM knowledge_document_source
# WHERE knowledge_document_source.business_id = ? AND knowledge_document_source.status = ? ORDER BY knowledge_document_source.id DESC
#  LIMIT ? OFFSET ?
# 2026-06-15 13:30:46,652 INFO sqlalchemy.engine.Engine [generated in 0.00076s] ('biz_nongnghiep_001', 'completed', 3, 0)
# 2026-06-15 13:30:46,654 INFO sqlalchemy.engine.Engine ROLLBACK
